# %%
# !pip install pyops
# Out:
# Requirement already satisfied: pyops in /misc/home/reco/reboutli/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages (0.0.2)
# Requirement already satisfied: requests in /misc/home/reco/reboutli/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages (from pyops) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /misc/home/reco/reboutli/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages (from requests->pyops) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /misc/home/reco/reboutli/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages (from requests->pyops) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /misc/home/reco/reboutli/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages (from requests->pyops) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /misc/home/reco/reboutli/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages (from requests->pyops) (2020.6.20)

# %%
import pyops
import logging
import json

# %%
# read config file first
with open('config.json', 'r') as f:
    config = json.load(f)
print(config)
# Out:
# {'PEPS_url': 'https://peps.cnes.fr/resto/api/collections/', 'PEPS_collections': ['S1', 'S2', 'S2ST', 'S3'], 'PEPS_formats': ['json', 'atom'], 'COP_url': 'https://scihub.copernicus.eu/dhus/search?q=', 'COP_user': '', 'COP_pwd': '', 'PAVICS_url': 'https://pavics.ouranos.ca/twitcher/ows/proxy/catalog/wps'}

# %% [markdown]
# # PEPS
# Les descripteurs Opensearch de PEPS sont:
# "https://peps.cnes.fr/resto/api/collections/{collection}/describe.xml"

# %%
parameters = {
    'resto_tileid' :  "31TCJ" #,
   # '{eo:cloudCover}' : {"value": '[10,70]'}
}
collection = "S2ST"

# %%
def PEPS_descr_url(collection):
    descr_URL = config['PEPS_url']
    if collection in config['PEPS_collections']:
      descr_URL += collection
    descr_URL += "/describe.xml"
    return descr_URL

# %%
descr_PEPS = PEPS_descr_url(collection)
print(descr_PEPS)
# Out:
# https://peps.cnes.fr/resto/api/collections/S2ST/describe.xml

# %%
logging.basicConfig(filename='example.log',level=logging.INFO)
# Client params
# specify either search_endpoint or description_xml_url
# type = 'collection' or 'results'
client = pyops.Client(description_xml_url=descr_PEPS, type='collection')
# search params: force_HTTPS=True, params={}, auth=()

# %%
# dir(client)

# %%
client.search_params
# Out:
# {'searchTerms': {'clean_tag': 'searchTerms',
#   'full_tag': '{searchTerms?}',
#   'type': 'text',
#   'title': 'Free text search'},
#  'productIdentifier': {'clean_tag': 'productIdentifier',
#   'full_tag': '{productIdentifier?}',
#   'type': 'text',
#   'title': 'Product identifier'},
#  'count': {'clean_tag': 'count',
#   'full_tag': '{count?}',
#   'type': 'text',
#   'title': 'Number of results returned per page (default 20, max 500)',
#   'minInclusive': '1',
#   'maxInclusive': '500'},
#  'startIndex': {'clean_tag': 'startIndex',
#   'full_tag': '{startIndex?}',
#   'type': 'text',
#   'title': 'Index of the first result returned',
#   'minInclusive': '1'},
#  'startPage': {'clean_tag': 'startPage',
#   'full_tag': '{startPage?}',
#   'type': 'text',
#   'title': 'Results page to return',
#   'minInclusive': '1'},
#  'language': {'clean_tag': 'language',
#   'full_tag': '{language?}',
#   'type': 'text',
#   'title': 'Two letters language code according to ISO 639-1',
#   'pattern': '^[a-z]{2}$'},
#  'geo_uid': {'clean_tag': 'geo:uid',
#   'full_tag': '{geo:uid?}',
#   'type': 'text',
#   'title': 'Either resto identifier or productIdentifier'},
#  'geo_geometry': {'clean_tag': 'geo:geometry',
#   'full_tag': '{geo:geometry?}',
#   'type': 'text',
#   'title': 'Defined in Well Known Text standard (WKT) with coordinates in decimal degrees (EPSG:4326)'},
#  'geo_box': {'clean_tag': 'geo:box',
#   'full_tag': '{geo:box?}',
#   'type': 'text',
#   'title': "Defined by 'west, south, east, north' coordinates of longitude, latitude, in decimal degrees (EPSG:4326)",
#   'pattern': '^[0-9\\.\\,\\-]*$'},
#  'geo_name': {'clean_tag': 'geo:name',
#   'full_tag': '{geo:name?}',
#   'type': 'text',
#   'title': 'Location string e.g. Paris, France'},
#  'geo_lon': {'clean_tag': 'geo:lon',
#   'full_tag': '{geo:lon?}',
#   'type': 'text',
#   'title': 'Longitude expressed in decimal degrees (EPSG:4326) - should be used with geo:lat',
#   'minInclusive': '-180',
#   'maxInclusive': '180'},
#  'geo_lat': {'clean_tag': 'geo:lat',
#   'full_tag': '{geo:lat?}',
#   'type': 'text',
#   'title': 'Latitude expressed in decimal degrees (EPSG:4326) - should be used with geo:lon',
#   'minInclusive': '-90',
#   'maxInclusive': '90'},
#  'geo_radius': {'clean_tag': 'geo:radius',
#   'full_tag': '{geo:radius?}',
#   'type': 'text',
#   'title': 'Expressed in meters - should be used with geo:lon and geo:lat',
#   'minInclusive': '1'},
#  'time_start': {'clean_tag': 'time:start',
#   'full_tag': '{time:start?}',
#   'type': 'date',
#   'title': 'Beginning of the time slice of the search query. Format should follow RFC-3339',
#   'pattern': '^[0-9]{4}-[0-9]{2}-[0-9]{2}(T[0-9]{2}:[0-9]{2}:[0-9]{2}(\\.[0-9]+)?(|Z|[\\+\\-][0-9]{2}:[0-9]{2}))?$'},
#  'time_end': {'clean_tag': 'time:end',
#   'full_tag': '{time:end?}',
#   'type': 'date',
#   'title': 'End of the time slice of the search query. Format should follow RFC-3339',
#   'pattern': '^[0-9]{4}-[0-9]{2}-[0-9]{2}(T[0-9]{2}:[0-9]{2}:[0-9]{2}(\\.[0-9]+)?(|Z|[\\+\\-][0-9]{2}:[0-9]{2}))?$'},
#  'eo_parentIdentifier': {'clean_tag': 'eo:parentIdentifier',
#   'full_tag': '{eo:parentIdentifier?}',
#   'type': 'text',
#   'title': 'Parent identifier'},
#  'eo_productType': {'clean_tag': 'eo:productType',
#   'full_tag': '{eo:productType?}',
#   'type': 'select',
#   'title': 'Product type',
#   'options': {'S2MSI1C': 'S2MSI1C',
#    'S2MSI2A': 'S2MSI2A',
#    'S2MSI2Ap': 'S2MSI2Ap'}},
#  'eo_processingLevel': {'clean_tag': 'eo:processingLevel',
#   'full_tag': '{eo:processingLevel?}',
#   'type': 'select',
#   'title': 'Processing level',
#   'options': {'LEVEL1C': 'LEVEL1C', 'LEVEL2A': 'LEVEL2A'}},
#  'eo_platform': {'clean_tag': 'eo:platform',
#   'full_tag': '{eo:platform?}',
#   'type': 'select',
#   'title': 'Mission/Satellite identifier (3 letters)',
#   'options': {'S2A': 'S2A', 'S2B': 'S2B'}},
#  'eo_instrument': {'clean_tag': 'eo:instrument',
#   'full_tag': '{eo:instrument?}',
#   'type': 'select',
#   'title': 'Instrument',
#   'options': {'MSI': 'MSI'}},
#  'eo_resolution': {'clean_tag': 'eo:resolution',
#   'full_tag': '{eo:resolution?}',
#   'type': 'text',
#   'title': 'Spatial resolution expressed in meters',
#   'pattern': '^(?:[1-9]\\d*|0)?(?:\\.\\d+)?$'},
#  'eo_organisationName': {'clean_tag': 'eo:organisationName',
#   'full_tag': '{eo:organisationName?}',
#   'type': 'text',
#   'title': 'Organisation name'},
#  'eo_orbitDirection': {'clean_tag': 'eo:orbitDirection',
#   'full_tag': '{eo:orbitDirection?}',
#   'type': 'select',
#   'title': 'Orbit direction',
#   'options': {'ascending': 'ascending', 'descending': 'descending'}},
#  'eo_orbitNumber': {'clean_tag': 'eo:orbitNumber',
#   'full_tag': '{eo:orbitNumber?}',
#   'type': 'text',
#   'title': 'Orbit number',
#   'minInclusive': '1'},
#  'eo_sensorMode': {'clean_tag': 'eo:sensorMode',
#   'full_tag': '{eo:sensorMode?}',
#   'type': 'select',
#   'title': 'Sensor mode',
#   'options': {'': '',
#    'INS-NOBS': 'INS-NOBS',
#    'INS-RAW': 'INS-RAW',
#    'INS-VIC': 'INS-VIC'}},
#  'eo_cloudCover': {'clean_tag': 'eo:cloudCover',
#   'full_tag': '{eo:cloudCover?}',
#   'type': 'text',
#   'title': 'Cloud cover expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'eo_snowCover': {'clean_tag': 'eo:snowCover',
#   'full_tag': '{eo:snowCover?}',
#   'type': 'text',
#   'title': 'Snow cover expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_cultivatedCover': {'clean_tag': 'resto:cultivatedCover',
#   'full_tag': '{resto:cultivatedCover?}',
#   'type': 'text',
#   'title': 'Cultivated area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_desertCover': {'clean_tag': 'resto:desertCover',
#   'full_tag': '{resto:desertCover?}',
#   'type': 'text',
#   'title': 'Desert area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_floodedCover': {'clean_tag': 'resto:floodedCover',
#   'full_tag': '{resto:floodedCover?}',
#   'type': 'text',
#   'title': 'Flooded area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_forestCover': {'clean_tag': 'resto:forestCover',
#   'full_tag': '{resto:forestCover?}',
#   'type': 'text',
#   'title': 'Forest area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_herbaceousCover': {'clean_tag': 'resto:herbaceousCover',
#   'full_tag': '{resto:herbaceousCover?}',
#   'type': 'text',
#   'title': 'Herbaceous area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_iceCover': {'clean_tag': 'resto:iceCover',
#   'full_tag': '{resto:iceCover?}',
#   'type': 'text',
#   'title': 'Ice area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_urbanCover': {'clean_tag': 'resto:urbanCover',
#   'full_tag': '{resto:urbanCover?}',
#   'type': 'text',
#   'title': 'Urban area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'resto_waterCover': {'clean_tag': 'resto:waterCover',
#   'full_tag': '{resto:waterCover?}',
#   'type': 'text',
#   'title': 'Water area expressed in percent',
#   'pattern': '^(\\[|\\]|[0-9])?[0-9]+$|^[0-9]+?(\\[|\\])$|^(\\[|\\])[0-9]+,[0-9]+(\\[|\\])$'},
#  'dc_date': {'clean_tag': 'dc:date',
#   'full_tag': '{dc:date?}',
#   'type': 'text',
#   'title': 'Last update of the product within database',
#   'pattern': '^[0-9]{4}-[0-9]{2}-[0-9]{2}(T[0-9]{2}:[0-9]{2}:[0-9]{2}(\\.[0-9]+)?(|Z|[\\+\\-][0-9]{2}:[0-9]{2}))?$'},
#  'resto_publishedBegin': {'clean_tag': 'resto:publishedBegin',
#   'full_tag': '{resto:publishedBegin?}',
#   'type': 'text',
#   'title': 'Begin publication date',
#   'pattern': '^[0-9]{4}-[0-9]{2}-[0-9]{2}(T[0-9]{2}:[0-9]{2}:[0-9]{2}(\\.[0-9]+)?(|Z|[\\+\\-][0-9]{2}:[0-9]{2}))?$'},
#  'resto_publishedEnd': {'clean_tag': 'resto:publishedEnd',
#   'full_tag': '{resto:publishedEnd?}',
#   'type': 'text',
#   'title': 'End publication date',
#   'pattern': '^[0-9]{4}-[0-9]{2}-[0-9]{2}(T[0-9]{2}:[0-9]{2}:[0-9]{2}(\\.[0-9]+)?(|Z|[\\+\\-][0-9]{2}:[0-9]{2}))?$'},
#  'resto_isNrt': {'clean_tag': 'resto:isNrt',
#   'full_tag': '{resto:isNrt?}',
#   'type': 'text',
#   'title': 'Near RealTime Products',
#   'minInclusive': '0',
#   'maxInclusive': '1'},
#  'resto_realtime': {'clean_tag': 'resto:realtime',
#   'full_tag': '{resto:realtime?}',
#   'type': 'select',
#   'title': 'Near RealTime Products',
#   'options': {'Nominal': 'Nominal'}},
#  'resto_relativeOrbitNumber': {'clean_tag': 'resto:relativeOrbitNumber',
#   'full_tag': '{resto:relativeOrbitNumber?}',
#   'type': 'text',
#   'title': 'Relative orbit number',
#   'minInclusive': '1'},
#  'resto_tileid': {'clean_tag': 'resto:tileid',
#   'full_tag': '{resto:tileid?}',
#   'type': 'text',
#   'title': 'MGRS tile identifier',
#   'pattern': '^[0-6][0-9][A-Za-z]([A-Za-z]){0,2}%?$'},
#  'resto_s2TakeId': {'clean_tag': 'resto:s2TakeId',
#   'full_tag': '{resto:s2TakeId?}',
#   'type': 'text',
#   'title': 'mission data take identifier',
#   'pattern': '^G(?:S2A|S2B)_\\d{8}T\\d{6}_\\d{6}_N\\d\\d\\.\\d\\d$'}}

# %%
client.search_param_names
# Out:
# {'q': 'searchTerms',
#  'productIdentifier': 'productIdentifier',
#  'maxRecords': 'count',
#  'index': 'startIndex',
#  'page': 'startPage',
#  'lang': 'language',
#  'identifier': 'geo_uid',
#  'geometry': 'geo_geometry',
#  'box': 'geo_box',
#  'location': 'geo_name',
#  'lon': 'geo_lon',
#  'lat': 'geo_lat',
#  'radius': 'geo_radius',
#  'startDate': 'time_start',
#  'completionDate': 'time_end',
#  'parentIdentifier': 'eo_parentIdentifier',
#  'productType': 'eo_productType',
#  'processingLevel': 'eo_processingLevel',
#  'platform': 'eo_platform',
#  'instrument': 'eo_instrument',
#  'resolution': 'eo_resolution',
#  'organisationName': 'eo_organisationName',
#  'orbitDirection': 'eo_orbitDirection',
#  'orbitNumber': 'eo_orbitNumber',
#  'sensorMode': 'eo_sensorMode',
#  'cloudCover': 'eo_cloudCover',
#  'snowCover': 'eo_snowCover',
#  'cultivatedCover': 'resto_cultivatedCover',
#  'desertCover': 'resto_desertCover',
#  'floodedCover': 'resto_floodedCover',
#  'forestCover': 'resto_forestCover',
#  'herbaceousCover': 'resto_herbaceousCover',
#  'iceCover': 'resto_iceCover',
#  'urbanCover': 'resto_urbanCover',
#  'waterCover': 'resto_waterCover',
#  'updated': 'dc_date',
#  'publishedBegin': 'resto_publishedBegin',
#  'publishedEnd': 'resto_publishedEnd',
#  'isNrt': 'resto_isNrt',
#  'realtime': 'resto_realtime',
#  'relativeOrbitNumber': 'resto_relativeOrbitNumber',
#  'tileid': 'resto_tileid',
#  's2TakeId': 'resto_s2TakeId'}

# %%
client = pyops.Client(description_xml_url=descr_PEPS, type='collection')

param_names = client.search_param_names
params = client.search_params
input_params = {}

form_fields = {"tileid":  "31TCJ", "page": "1", 'maxRecords': '50', 'cloudCover': '[10,70]'}
for ff in form_fields:
    value = form_fields[ff]
    if value and ff in param_names:
        print(params[param_names[ff]]["full_tag"])
        input_params[params[param_names[ff]]["full_tag"]] = {"value": value}

# Get Raw Results
raw_results = client.search(params=input_params)
print("total number of results:", client.pagination['total_results'])
print("last page:", client.pagination['last'] )
form_fields = client.pagination['next']
while True:
    print(form_fields)
    for ff in form_fields:
        value = form_fields[ff]
        if value and ff in param_names:
            input_params[params[param_names[ff]]["full_tag"]] = {"value": value}
    client = pyops.Client(description_xml_url=descr_PEPS, type='collection')
    new_raw_results = client.search(params=input_params)
    print(len(new_raw_results))
    assert raw_results[0] != new_raw_results[0]
    raw_results = new_raw_results
    print("last page", client.pagination['last'] )
    
    if form_fields == client.pagination['last'] :
        break
    form_fields = client.pagination['next']
    input_params = {}

print(raw_results)
# Out:
# {resto:tileid?}
# {startPage?}
# {count?}
# {eo:cloudCover?}
# https://peps.cnes.fr/resto/api/collections/S2ST/search.atom?maxRecords=50&page=1&cloudCover=[10,70]&tileid=31TCJ
# total number of results: 209
# last page: {'maxRecords': '50', 'page': '5', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# {'maxRecords': '50', 'page': '2', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# https://peps.cnes.fr/resto/api/collections/S2ST/search.atom?maxRecords=50&page=2&cloudCover=%5B10%2C70%5D&tileid=31TCJ
# 50
# last page {'maxRecords': '50', 'page': '5', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# {'maxRecords': '50', 'page': '3', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# https://peps.cnes.fr/resto/api/collections/S2ST/search.atom?maxRecords=50&page=3&cloudCover=%5B10%2C70%5D&tileid=31TCJ
# 50
# last page {'maxRecords': '50', 'page': '5', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# {'maxRecords': '50', 'page': '4', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# https://peps.cnes.fr/resto/api/collections/S2ST/search.atom?maxRecords=50&page=4&cloudCover=%5B10%2C70%5D&tileid=31TCJ
# 50
# last page {'maxRecords': '50', 'page': '5', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# {'maxRecords': '50', 'page': '5', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# https://peps.cnes.fr/resto/api/collections/S2ST/search.atom?maxRecords=50&page=5&cloudCover=%5B10%2C70%5D&tileid=31TCJ
# 50
# last page {'maxRecords': '50', 'page': '5', 'cloudCover': '%5B10%2C70%5D', 'tileid': '31TCJ'}
# [[{'tag': '{http://www.w3.org/2005/Atom}id', 'name': 'id', 'attrs': {}, 'text': '18774abf-45f9-54f7-8b02-0ff591a576d6', 'children': []}, {'tag': '{http://purl.org/dc/elements/1.1/}identifier', 'name': 'identifier', 'attrs': {}, 'text': '18774abf-45f9-54f7-8b02-0ff591a576d6', 'children': []}, {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2B_MSIL1C_20180202T104239_N0206_R008_T31TCJ_20180202T124858', 'children': []}, {'tag': '{http://www.w3.org/2005/Atom}published', 'name': 'published', 'attrs': {}, 'text': '2018-02-03T09:15:30.138Z', 'children': []}, {'tag': '{http://www.w3.org/2005/Atom}updated', 'name': 'updated', 'attrs': {}, 'text': '2018-02-03T09:15:30.138Z', 'children': []}, {'tag': '{http://purl.org/dc/elements/1.1/}date', 'name': 'date', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z/2018-02-02T10:42:39.027Z', 'children': []}, {'tag': '{http://www.opengis.net/gml}validTime', 'name': 'validTime', 'attrs': {}, 'text': '\n   ', 'children': [{'tag': '{http://www.opengis.net/gml}TimePeriod', 'name': 'TimePeriod', 'attrs': {}, 'text': '\n    ', 'children': [[{'tag': '{http://www.opengis.net/gml}beginPosition', 'name': 'beginPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}], [{'tag': '{http://www.opengis.net/gml}endPosition', 'name': 'endPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}]]}, {'tag': '{http://www.opengis.net/gml}beginPosition', 'name': 'beginPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}, {'tag': '{http://www.opengis.net/gml}endPosition', 'name': 'endPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}]}, {'tag': '{http://www.opengis.net/gml}TimePeriod', 'name': 'TimePeriod', 'attrs': {}, 'text': '\n    ', 'children': [[{'tag': '{http://www.opengis.net/gml}beginPosition', 'name': 'beginPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}], [{'tag': '{http://www.opengis.net/gml}endPosition', 'name': 'endPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}]]}, {'tag': '{http://www.opengis.net/gml}beginPosition', 'name': 'beginPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}, {'tag': '{http://www.opengis.net/gml}endPosition', 'name': 'endPosition', 'attrs': {}, 'text': '2018-02-02T10:42:39.027Z', 'children': []}, {'tag': '{http://www.georss.org/georss}where', 'name': 'where', 'attrs': {}, 'text': '\n   ', 'children': [{'tag': '{http://www.opengis.net/gml}Polygon', 'name': 'Polygon', 'attrs': {}, 'text': '\n    ', 'children': [{'tag': '{http://www.opengis.net/gml}exterior', 'name': 'exterior', 'attrs': {}, 'text': '\n     ', 'children': [{'tag': '{http://www.opengis.net/gml}LinearRing', 'name': 'LinearRing', 'attrs': {}, 'text': '\n      ', 'children': [{'tag': '{http://www.opengis.net/gml}posList', 'name': 'posList', 'attrs': {'srsDimensions': '2'}, 'text': '43.253155660068 1.4896716482878 43.39758383192 1.5363501137257 43.544469956006 1.5843307609475 43.691356836459 1.6325271729477 43.83819959619 1.6809617905548 43.984956649414 1.7297528778594 44.131695882062 1.7786502611415 44.246983860522 1.8170145364248 44.247830683969 1.8702372867615 43.259391910537 1.8886830141923 43.253155660068 1.4896716482878', 'children': []}]}, {'tag': '{http://www.opengis.net/gml}posList', 'name': 'posList', 'attrs': {'srsDimensions': '2'}, 'text': '43.253155660068 1.4896716482878 43.39758383192 1.5363501137257 43.544469956006 1.5843307609475 43.691356836459 1.6325271729477 43.83819959619 1.6809617905548 43.984956649414 1.7297528778594 44.131695882062 1.7786502611415 44.246983860522 1.8170145364248 44.247830683969 1.8702372867615 43.259391910537 1.8886830141923 43.253155660068 1.4896716482878', 'children': []}]}, {'tag': '{http://www.opengis.net/gml}LinearRing', 'name': 'LinearRing', 'attrs': {}, 'text': '\n      ', 'children': [{'tag': '{http://www.opengis.net/gml}posList', 'name': 'posList', 'attrs': {'srsDimensions': '2' ...

# %%
entry_fields = client.get_available_fields()
filtered_results = client.filter_entries([{
    "tag": "{http://www.w3.org/2005/Atom}title",
    "name": "title"}, {
    "tag": "{http://www.w3.org/2005/Atom}summary",
    "name": "summary"}])
for results in filtered_results:
    for res in results:
        print(res)
# Out:
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20UPD_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19UGR_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20TMR_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19TGJ_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20ULV_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19TGL_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20UNU_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19TGK_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19UGS_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20UNC_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19UFS_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20TLQ_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19UGV_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20UME_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19TEK_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20TMT_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19TGN_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20TLS_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T19UFR_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}title', 'name': 'title', 'attrs': {}, 'text': 'S2A_MSIL1C_20200918T152631_N0209_R068_T20UNF_20200918T171831', 'children': []}
# {'tag': '{http://www.w3.org/2005/Atom}summary', 'name': 'summary', 'attrs': {'type': 'text'}, 'text': 'S2A/MSI acquired on 2020-09-18T15:26:31.024Z', 'children': []}
