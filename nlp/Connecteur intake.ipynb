# %%
# all imports for this notebook
import intake
import satsearch
from satstac import ItemCollection
from lxml import objectify, etree
# Out:
# /home/bagositi/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages/fastprogress/fastprogress.py:102: UserWarning: Couldn't import ipywidgets properly, progress bar will use console behavior
#   warn("Couldn't import ipywidgets properly, progress bar will use console behavior")

# %% [markdown]
# 1. requete PEPS (Sentinel-Hub) avec intake-STAC

# %%
#Q? find catalog.json under these URLs
sentinel_hub_catalogue = "https://services.sentinel-hub.com/api/v1/catalog/"
sentinel_hub_search = "https://services.sentinel-hub.com/api/v1/catalog/search"

# %% [markdown]
# Landsat-8 example

# %%
landsat8_url = "https://raw.githubusercontent.com/sat-utils/sat-stac/master/test/catalog/catalog.json"
cat = intake.open_stac_catalog(landsat8_url)
list(cat)
# Out:
# ['stac-catalog-eo']

# %%
cat.metadata
# Out:
# {'id': 'stac-catalog',
#  'description': 'An example STAC catalog',
#  'stac_version': '1.0.0-beta.1'}

# %%
list(cat['stac-catalog-eo'])
# Out:
# ['sentinel-s2-l1c', 'landsat-8-l1']

# %%
ls8 = cat['stac-catalog-eo']['landsat-8-l1']
list(ls8)
# Out:
# ['LC08_L1TP_152038_20200611_20200611_01_RT']

# %%
ls8_item = ls8['LC08_L1TP_152038_20200611_20200611_01_RT']
list(ls8_item)
# Out:
# ['ANG',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B8',
#  'B9',
#  'B10',
#  'B11',
#  'BQA',
#  'MTL',
#  'thumbnail',
#  'index']

# %%
ls8_item.metadata
# Out:
# {'datetime': datetime.datetime(2020, 6, 11, 5, 54, 44, 650000, tzinfo=tzutc()),
#  'gsd': 30,
#  'platform': 'landsat-8',
#  'instruments': ['oli', 'tirs'],
#  'eo:cloud_cover': 6,
#  'view:off_nadir': 0,
#  'view:azimuth': 0,
#  'view:sun_azimuth': 108.63187979,
#  'view:sun_elevation': 68.84430949,
#  'landsat:path': 107,
#  'landsat:row': 18,
#  'landsat:earth_sun_distance': 1.014156,
#  'landsat:ground_control_points_verify': 114,
#  'landsat:geometric_rmse_model': 7.562,
#  'landsat:image_quality_tirs': 9,
#  'landsat:ground_control_points_model': 313,
#  'landsat:geometric_rmse_model_x': 5.96,
#  'landsat:geometric_rmse_model_y': 4.654,
#  'landsat:geometric_rmse_verify': 5.364,
#  'landsat:image_quality_oli': 9,
#  'bbox': [49.16354, 72.27502, 51.36812, 75.67662],
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[51.33855, 72.27502],
#     [51.36812, 75.70821],
#     [49.19092, 75.67662],
#     [49.16354, 72.3964],
#     [51.33855, 72.27502]]]},
#  'date': datetime.date(2020, 6, 11),
#  'catalog_dir': ''}

# %%
cat.search('instruments')
# Out:
# stac-catalog_search:
#   args:
#     auth: !!python/object:intake.auth.base.BaseClientAuth
#       args: !!python/tuple []
#     getenv: true
#     getshell: true
#     name: stac-catalog_search
#     storage_options: null
#     ttl: 1
#   description: ''
#   driver: intake.catalog.base.Catalog
#   metadata:
#     description: An example STAC catalog
#     id: stac-catalog
#     search:
#       text: instruments
#       upstream: stac-catalog
#     stac_version: 1.0.0-beta.1

# %% [markdown]
# SAT-SEARCH
# Trying: Search functionality over STAC APIs: https://github.com/sat-utils/sat-search/blob/master/tutorial-1.ipynb

# %%
URL =  "https://earth-search.aws.element84.com/v0"
results = satsearch.Search.search(url=URL,
                                bbox=[-110, 39.5, -105, 40.5],
                               datetime='2018-02-12T00:00:00Z/2018-03-18T12:31:12Z',
                               query=["eo:cloud_cover<10"],
                               collections=['sentinel-s2-l2a'])

print('Found %s items' % results.found())                                  
items = results.items(limit=5)
print('Summary: %s' % items.summary())

print('%s collections' % len(items._collections))
col = items._collections[0]
print('Collection: %s' % col)
#for key in col.keys():
#    print('%s: %s' % (key, col[key]))
    
print('\nITEMS: ')
for item in items:
    print('\nid: ',item.id)
    print('coll: ', item.collection())
    
    print("\nPROPERTIES:")
    print(item.properties.keys())
    for key in item.properties:
        print('%s: %s' % (key, item.properties[key]))
    
    print("\nASSETS: ")
    print(item.assets.keys())
    for key in item.assets.keys():
        print('%s: %s' % (key, item.assets[key]))
    break #just print first
# Out:
# There are more items found (27) than the limit (5) provided.
# Found 27 items
# Summary: Items (27):
# date                      id
# 2018-03-16                S2B_12SXJ_20180316_1_L2A
# 2018-03-16                S2B_12TWK_20180316_0_L2A
# 2018-03-15                S2A_13TEE_20180315_0_L2A
# 2018-03-13                S2B_13TEE_20180313_0_L2A
# 2018-03-13                S2B_13SED_20180313_0_L2A
# 2018-03-11                S2A_12TWK_20180311_0_L2A
# 2018-03-08                S2A_13SDD_20180308_0_L2A
# 2018-03-08                S2A_13TEE_20180308_0_L2A
# 2018-03-08                S2A_13SBD_20180308_0_L2A
# 2018-03-08                S2A_13TDE_20180308_0_L2A
# 2018-03-08                S2A_12SYJ_20180308_0_L2A
# 2018-03-08                S2A_13SED_20180308_0_L2A
# 2018-03-08                S2A_12TYK_20180308_0_L2A
# 2018-02-27                S2B_12SXJ_20180227_0_L2A
# 2018-02-27                S2B_12TXK_20180227_0_L2A
# 2018-02-23                S2A_13SED_20180223_0_L2A
# 2018-02-17                S2B_12SWJ_20180217_0_L2A
# 2018-02-17                S2B_12SXJ_20180217_0_L2A
# 2018-02-17                S2B_12TXK_20180217_0_L2A
# 2018-02-17                S2B_12TWK_20180217_0_L2A
# 2018-02-16                S2A_13TEE_20180216_0_L2A
# 2018-02-13                S2A_13SDD_20180213_0_L2A
# 2018-02-13                S2A_13TEE_20180213_0_L2A
# 2018-02-13                S2A_13TDE_20180213_0_L2A
# 2018-02-13                S2A_13SED_20180213_0_L2A
# 2018-02-12                S2A_12SWJ_20180212_0_L2A
# 2018-02-12                S2A_12TXK_20180212_1_L2A
#
# 1 collections
# Collection: sentinel-s2-l2a
#
# ITEMS:
#
# id:  S2B_12SXJ_20180316_1_L2A
# coll:  sentinel-s2-l2a
#
# PROPERTIES:
# dict_keys(['datetime', 'platform', 'constellation', 'instruments', 'gsd', 'view:off_nadir', 'proj:epsg', 'sentinel:latitude_band', 'sentinel:grid_square', 'sentinel:sequence', 'sentinel:product_id', 'sentinel:data_coverage', 'eo:cloud_cover', 'sentinel:valid_cloud_cover', 'created', 'updated', 'sentinel:utm_zone'])
# datetime: 2018-03-16T18:10:19Z
# platform: sentinel-2b
# constellation: sentinel-2
# instruments: ['msi']
# gsd: 10
# view:off_nadir: 0
# proj:epsg: 32612
# sentinel:latitude_band: S
# sentinel:grid_square: XJ
# sentinel:sequence: 1
# sentinel:product_id: S2B_MSIL2A_20180316T180059_N0001_R041_T12SXJ_20200715T165611
# sentinel:data_coverage: 100
# eo:cloud_cover: 0
# sentinel:valid_cloud_cover: False
# created: 2020-08-30T07:31:35.399Z
# updated: 2020-08-30T07:31:35.399Z
# sentinel:utm_zone: 12
#
# ASSETS:
# dict_keys(['thumbnail', 'overview', 'info', 'metadata', 'visual', 'visual_20m', 'visual_60m', 'B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B09', 'B11', 'B12', 'AOT', 'WVP', 'SCL'])
# thumbnail: {'title': 'Thumbnail', 'type': 'image/png', 'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/12/S/XJ/2018/3/16/1/preview.jpg', 'roles': ['thumbnail']}
# overview: {'title': 'True color image', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/qi/L2A_PVI.jp2', 'roles': ['overview'], 'eo:bands': [{'full_width_half_max': 0.038, 'center_wavelength': 0.6645, 'name': 'B04', 'common_name': 'red'}, {'full_width_half_max': 0.045, 'center_wavelength': 0.56, 'name': 'B03', 'common_name': 'green'}, {'full_width_half_max': 0.098, 'center_wavelength': 0.4966, 'name': 'B02', 'common_name': 'blue'}], 'gsd': 10}
# info: {'title': 'Original JSON metadata', 'type': 'application/json', 'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/tileInfo.json', 'roles': ['metadata']}
# metadata: {'title': 'Original XML metadata', 'type': 'application/xml', 'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/metadata.xml', 'roles': ['metadata']}
# visual: {'title': 'True color image', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R10m/TCI.jp2', 'roles': ['overview'], 'eo:bands': [{'full_width_half_max': 0.038, 'center_wavelength': 0.6645, 'name': 'B04', 'common_name': 'red'}, {'full_width_half_max': 0.045, 'center_wavelength': 0.56, 'name': 'B03', 'common_name': 'green'}, {'full_width_half_max': 0.098, 'center_wavelength': 0.4966, 'name': 'B02', 'common_name': 'blue'}], 'gsd': 10}
# visual_20m: {'title': 'True color image', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/TCI.jp2', 'roles': ['overview'], 'eo:bands': [{'full_width_half_max': 0.038, 'center_wavelength': 0.6645, 'name': 'B04', 'common_name': 'red'}, {'full_width_half_max': 0.045, 'center_wavelength': 0.56, 'name': 'B03', 'common_name': 'green'}, {'full_width_half_max': 0.098, 'center_wavelength': 0.4966, 'name': 'B02', 'common_name': 'blue'}], 'gsd': 20}
# visual_60m: {'title': 'True color image', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R60m/TCI.jp2', 'roles': ['overview'], 'eo:bands': [{'full_width_half_max': 0.038, 'center_wavelength': 0.6645, 'name': 'B04', 'common_name': 'red'}, {'full_width_half_max': 0.045, 'center_wavelength': 0.56, 'name': 'B03', 'common_name': 'green'}, {'full_width_half_max': 0.098, 'center_wavelength': 0.4966, 'name': 'B02', 'common_name': 'blue'}], 'gsd': 60}
# B01: {'title': 'Band 1 (coastal)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R60m/B01.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.027, 'center_wavelength': 0.4439, 'name': 'B01', 'common_name': 'coastal'}], 'gsd': 60}
# B02: {'title': 'Band 2 (blue)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R10m/B02.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.098, 'center_wavelength': 0.4966, 'name': 'B02', 'common_name': 'blue'}], 'gsd': 10}
# B03: {'title': 'Band 3 (green)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R10m/B03.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.045, 'center_wavelength': 0.56, 'name': 'B03', 'common_name': 'green'}], 'gsd': 10}
# B04: {'title': 'Band 4 (red)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R10m/B04.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.038, 'center_wavelength': 0.6645, 'name': 'B04', 'common_name': 'red'}], 'gsd': 10}
# B05: {'title': 'Band 5', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/B05.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.019, 'center_wavelength': 0.7039, 'name': 'B05'}], 'gsd': 20}
# B06: {'title': 'Band 6', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/B06.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.018, 'center_wavelength': 0.7402, 'name': 'B06'}], 'gsd': 20}
# B07: {'title': 'Band 7', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/B07.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.028, 'center_wavelength': 0.7825, 'name': 'B07'}], 'gsd': 20}
# B08: {'title': 'Band 8 (nir)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R10m/B08.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.145, 'center_wavelength': 0.8351, 'name': 'B08', 'common_name': 'nir'}], 'gsd': 10}
# B8A: {'title': 'Band 8A', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/B8A.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.033, 'center_wavelength': 0.8648, 'name': 'B8A'}], 'gsd': 20}
# B09: {'title': 'Band 9', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R60m/B09.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.026, 'center_wavelength': 0.945, 'name': 'B09'}], 'gsd': 60}
# B11: {'title': 'Band 11 (swir16)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/B11.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.143, 'center_wavelength': 1.6137, 'name': 'B11', 'common_name': 'swir16'}], 'gsd': 20}
# B12: {'title': 'Band 12 (swir22)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/B12.jp2', 'roles': ['data'], 'eo:bands': [{'full_width_half_max': 0.242, 'center_wavelength': 2.22024, 'name': 'B12', 'common_name': 'swir22'}], 'gsd': 20}
# AOT: {'title': 'Aerosol Optical Thickness (AOT)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R60m/AOT.jp2', 'roles': ['data']}
# WVP: {'title': 'Water Vapour (WVP)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R10m/WVP.jp2', 'roles': ['data']}
# SCL: {'title': 'Scene Classification Map (SCL)', 'type': 'image/jp2', 'href': 's3://sentinel-s2-l2a/tiles/12/S/XJ/2018/3/16/1/R20m/SCL.jp2', 'roles': ['data']}

# %%
#save and load items collection to json
items.save('test.json')
items2 = ItemCollection.open('test.json')

print(items2.summary(['date', 'id', 'eo:cloud_cover']))
# Out:
# Items (27):
# date                      id                        eo:cloud_cover
# 2018-03-16                S2B_12SXJ_20180316_1_L2A  0
# 2018-03-16                S2B_12TWK_20180316_0_L2A  8.5
# 2018-03-15                S2A_13TEE_20180315_0_L2A  1.2
# 2018-03-13                S2B_13TEE_20180313_0_L2A  0
# 2018-03-13                S2B_13SED_20180313_0_L2A  3.42
# 2018-03-11                S2A_12TWK_20180311_0_L2A  3.85
# 2018-03-08                S2A_13SDD_20180308_0_L2A  9.89
# 2018-03-08                S2A_13TEE_20180308_0_L2A  0.11
# 2018-03-08                S2A_13SBD_20180308_0_L2A  2.8
# 2018-03-08                S2A_13TDE_20180308_0_L2A  9.86
# 2018-03-08                S2A_12SYJ_20180308_0_L2A  0.6
# 2018-03-08                S2A_13SED_20180308_0_L2A  5.66
# 2018-03-08                S2A_12TYK_20180308_0_L2A  4.29
# 2018-02-27                S2B_12SXJ_20180227_0_L2A  9.61
# 2018-02-27                S2B_12TXK_20180227_0_L2A  1.9
# 2018-02-23                S2A_13SED_20180223_0_L2A  4.27
# 2018-02-17                S2B_12SWJ_20180217_0_L2A  1.79
# 2018-02-17                S2B_12SXJ_20180217_0_L2A  1.9
# 2018-02-17                S2B_12TXK_20180217_0_L2A  0.28
# 2018-02-17                S2B_12TWK_20180217_0_L2A  3.58
# 2018-02-16                S2A_13TEE_20180216_0_L2A  4.82
# 2018-02-13                S2A_13SDD_20180213_0_L2A  3.13
# 2018-02-13                S2A_13TEE_20180213_0_L2A  0.42
# 2018-02-13                S2A_13TDE_20180213_0_L2A  0
# 2018-02-13                S2A_13SED_20180213_0_L2A  0.74
# 2018-02-12                S2A_12SWJ_20180212_0_L2A  0
# 2018-02-12                S2A_12TXK_20180212_1_L2A  0

# %%
# download a specific asset from all items and put in a directory by date in 'downloads'
filenames = items.download('metadata', filename_template='downloads/${id}')
print(filenames)
# Out:
# ['downloads/S2B_12SXJ_20180316_1_L2A_metadata.xml', 'downloads/S2B_12TWK_20180316_0_L2A_metadata.xml', 'downloads/S2A_13TEE_20180315_0_L2A_metadata.xml', 'downloads/S2B_13TEE_20180313_0_L2A_metadata.xml', 'downloads/S2B_13SED_20180313_0_L2A_metadata.xml', 'downloads/S2A_12TWK_20180311_0_L2A_metadata.xml', 'downloads/S2A_13SDD_20180308_0_L2A_metadata.xml', 'downloads/S2A_13TEE_20180308_0_L2A_metadata.xml', 'downloads/S2A_13SBD_20180308_0_L2A_metadata.xml', 'downloads/S2A_13TDE_20180308_0_L2A_metadata.xml', 'downloads/S2A_12SYJ_20180308_0_L2A_metadata.xml', 'downloads/S2A_13SED_20180308_0_L2A_metadata.xml', 'downloads/S2A_12TYK_20180308_0_L2A_metadata.xml', 'downloads/S2B_12SXJ_20180227_0_L2A_metadata.xml', 'downloads/S2B_12TXK_20180227_0_L2A_metadata.xml', 'downloads/S2A_13SED_20180223_0_L2A_metadata.xml', 'downloads/S2B_12SWJ_20180217_0_L2A_metadata.xml', 'downloads/S2B_12SXJ_20180217_0_L2A_metadata.xml', 'downloads/S2B_12TXK_20180217_0_L2A_metadata.xml', 'downloads/S2B_12TWK_20180217_0_L2A_metadata.xml', 'downloads/S2A_13TEE_20180216_0_L2A_metadata.xml', 'downloads/S2A_13SDD_20180213_0_L2A_metadata.xml', 'downloads/S2A_13TEE_20180213_0_L2A_metadata.xml', 'downloads/S2A_13TDE_20180213_0_L2A_metadata.xml', 'downloads/S2A_13SED_20180213_0_L2A_metadata.xml', 'downloads/S2A_12SWJ_20180212_0_L2A_metadata.xml', 'downloads/S2A_12TXK_20180212_1_L2A_metadata.xml']

# %%
# inspect a metadata file
input_file = 'downloads/S2B_12SXJ_20180316_1_L2A_metadata.xml'
root = objectify.parse(input_file)
print(etree.tostring(root))
# Out:
# b'<n1:Level-2A_Tile_ID xmlns:n1="https://psd-14.sentinel2.eo.esa.int/PSD/S2_PDI_Level-2A_Tile_Metadata.xsd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="https://psd-14.sentinel2.eo.esa.int/PSD/S2_PDI_Level-2A_Tile_Metadata.xsd /dpc/app/s2ipf/FORMAT_METADATA_TILE_L1C/02.11.01/scripts/../../../schemas/02.13.01/PSD/S2_PDI_Level-2A_Tile_Metadata.xsd"><n1:General_Info><L1C_TILE_ID metadataLevel="Brief">S2B_OPER_MSI_L1C_TL_SGS__20180316T195810_A005358_T12SXJ_N02.06</L1C_TILE_ID><TILE_ID metadataLevel="Brief">S2B_OPER_MSI_L2A_TL_SHIT_20200715T165612_A005358_T12SXJ_N00.01</TILE_ID><DATASTRIP_ID metadataLevel="Standard">S2B_OPER_MSI_L2A_DS_SHIT_20200715T165612_S20180316T181019_N00.01</DATASTRIP_ID><DOWNLINK_PRIORITY metadataLevel="Standard">NOMINAL</DOWNLINK_PRIORITY><SENSING_TIME metadataLevel="Standard">2018-03-16T18:10:19.274Z</SENSING_TIME><Archiving_Info metadataLevel="Expertise"><ARCHIVING_CENTRE>SGS_</ARCHIVING_CENTRE><ARCHIVING_TIME>2020-07-15T17:54:56.598Z</ARCHIVING_TIME></Archiving_Info></n1:General_Info><n1:Geometric_Info><Tile_Geocoding metadataLevel="Brief"><HORIZONTAL_CS_NAME>WGS84 / UTM zone 12N</HORIZONTAL_CS_NAME><HORIZONTAL_CS_CODE>EPSG:32612</HORIZONTAL_CS_CODE><Size resolution="10"><NROWS>10980</NROWS><NCOLS>10980</NCOLS></Size><Size resolution="20"><NROWS>5490</NROWS><NCOLS>5490</NCOLS></Size><Size resolution="60"><NROWS>1830</NROWS><NCOLS>1830</NCOLS></Size><Geoposition resolution="10"><ULX>600000</ULX><ULY>4400040</ULY><XDIM>10</XDIM><YDIM>-10</YDIM></Geoposition><Geoposition resolution="20"><ULX>600000</ULX><ULY>4400040</ULY><XDIM>20</XDIM><YDIM>-20</YDIM></Geoposition><Geoposition resolution="60"><ULX>600000</ULX><ULY>4400040</ULY><XDIM>60</XDIM><YDIM>-60</YDIM></Geoposition></Tile_Geocoding><Tile_Angles metadataLevel="Standard"><Sun_Angles_Grid><Zenith><COL_STEP unit="m">5000</COL_STEP><ROW_STEP unit="m">5000</ROW_STEP><Values_List><VALUES>44.7043 44.6836 44.6628 44.6421 44.6214 44.6008 44.5802 44.5596 44.539 44.5185 44.4979 44.4775 44.457 44.4366 44.4162 44.3958 44.3754 44.3551 44.3348 44.3145 44.2943 44.2741 44.2539</VALUES><VALUES>44.6634 44.6427 44.6219 44.6012 44.5805 44.5598 44.5392 44.5186 44.498 44.4775 44.4569 44.4364 44.416 44.3955 44.3751 44.3547 44.3343 44.314 44.2937 44.2734 44.2532 44.233 44.2128</VALUES><VALUES>44.6225 44.6017 44.581 44.5603 44.5396 44.5189 44.4982 44.4776 44.457 44.4365 44.4159 44.3954 44.3749 44.3545 44.334 44.3136 44.2933 44.2729 44.2526 44.2323 44.2121 44.1918 44.1716</VALUES><VALUES>44.5816 44.5608 44.5401 44.5193 44.4986 44.4779 44.4573 44.4366 44.416 44.3955 44.3749 44.3544 44.3339 44.3134 44.293 44.2726 44.2522 44.2318 44.2115 44.1912 44.171 44.1507 44.1305</VALUES><VALUES>44.5407 44.5199 44.4992 44.4784 44.4577 44.437 44.4163 44.3957 44.3751 44.3545 44.3339 44.3134 44.2929 44.2724 44.252 44.2315 44.2111 44.1908 44.1704 44.1501 44.1298 44.1096 44.0894</VALUES><VALUES>44.4999 44.479 44.4583 44.4375 44.4168 44.3961 44.3754 44.3547 44.3341 44.3135 44.2929 44.2724 44.2519 44.2314 44.2109 44.1905 44.1701 44.1497 44.1294 44.109 44.0887 44.0685 44.0482</VALUES><VALUES>44.459 44.4382 44.4174 44.3966 44.3758 44.3551 44.3344 44.3138 44.2931 44.2725 44.2519 44.2314 44.2109 44.1904 44.1699 44.1494 44.129 44.1086 44.0883 44.0679 44.0476 44.0274 44.0071</VALUES><VALUES>44.4181 44.3973 44.3765 44.3557 44.3349 44.3142 44.2935 44.2728 44.2522 44.2315 44.2109 44.1904 44.1698 44.1493 44.1288 44.1084 44.088 44.0676 44.0472 44.0269 44.0065 43.9863 43.966</VALUES><VALUES>44.3772 44.3564 44.3356 44.3148 44.294 44.2733 44.2525 44.2319 44.2112 44.1906 44.17 44.1494 44.1288 44.1083 44.0878 44.0674 44.0469 44.0265 44.0061 43.9858 43.9655 43.9452 43.9249</VALUES><VALUES>44.3364 44.3155 44.2947 44.2739 44.2531 44.2323 44.2116 44.1909 44.1702 44.1496 44.129 44.1084 44.0878 44.0673 44.0468 44.0263 44.0059 43.9855 43.9651 43.9447 43.9244 43.9041 43.8838</VALUES><VALUES>44.2955 44.2746 44.2538 44.233 44.2122 44.1914 44.1707 44.15 44.1293 44.1086 44.088 44.0674 44.0468 44.02 ...

# %% [markdown]
# INTAKE-ESM

# %%
col_url = "https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json"
col = intake.open_esm_datastore(col_url)
col
# Out:
# /home/bagositi/miniconda3/envs/daccs-nlp/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <p><strong>pangeo-cmip6 catalog with 6539 dataset(s) from 402033 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>160</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>549</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>707</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>402033</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>802</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
col_subset = col.search(
         experiment_id=["historical", "ssp585"],
         table_id="Oyr",
         variable_id="o2",
         grid_label="gn",
)
col_subset
# Out:
# <p><strong>pangeo-cmip6 catalog with 23 dataset(s) from 149 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table>
# </div>
